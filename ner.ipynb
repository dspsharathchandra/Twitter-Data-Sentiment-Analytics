# %%
import pandas as pd 
pd.read_pickle('tweets_sentiment_ner_parsed.pkl')
# Out:
# 2022-05-04 16:01:49.922340: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-04 16:01:49.922354: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0       Date                        Location  \
# 0                0 2022-04-26                             NaN
# 1                1 2022-04-26                      London, UK
# 2                2 2022-04-26                          Canada
# 3                3 2022-04-26  America!!! Other places suck!
# 4                4 2022-04-26                          Canada
# ...            ...        ...                             ...
# 197271      197271 2022-01-14                          Canada
# 197272      197272 2022-01-14                Around the world
# ...
